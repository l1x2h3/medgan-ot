# %%
# import requirement libraries and tools
from tensorflow import keras
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style= "darkgrid", color_codes = True)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Conv2DTranspose, Reshape, BatchNormalization, Dropout, Input, ReLU, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.losses import BinaryCrossentropy
from PIL import Image
import os
from sklearn.model_selection import train_test_split
import pandas as pd
import random

import warnings
warnings.filterwarnings('ignore')

# %%
# !unzip /content/archive_5.zip -d /content/image_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/image_dataset/healthy/0402.jpg
#   inflating: /content/image_dataset/healthy/0403.jpg
#   inflating: /content/image_dataset/healthy/0404.jpg
#   inflating: /content/image_dataset/healthy/0405.jpg
#   inflating: /content/image_dataset/healthy/0406.jpg
#   inflating: /content/image_dataset/healthy/0407.jpg
#   inflating: /content/image_dataset/healthy/0408.jpg
#   inflating: /content/image_dataset/healthy/0409.jpg
#   inflating: /content/image_dataset/healthy/0410.jpg
#   inflating: /content/image_dataset/healthy/0411.jpg
#   inflating: /content/image_dataset/healthy/0412.jpg
#   inflating: /content/image_dataset/healthy/0413.jpg
#   inflating: /content/image_dataset/healthy/0414.jpg
#   inflating: /content/image_dataset/healthy/0415.jpg
#   inflating: /content/image_dataset/healthy/0416.jpg
#   inflating: /content/image_dataset/healthy/0417.jpg
#   inflating: /content/image_dataset/healthy/0418.jpg
#   inflating: /content/image_dataset/healthy/0419.jpg
#   inflating: /content/image_dataset/healthy/0420.jpg
#   inflating: /content/image_dataset/healthy/0421.jpg
#   inflating: /content/image_dataset/healthy/0422.jpg
#   inflating: /content/image_dataset/healthy/0423.jpg
#   inflating: /content/image_dataset/healthy/0424.jpg
#   inflating: /content/image_dataset/healthy/0425.jpg
#   inflating: /content/image_dataset/healthy/0426.jpg
#   inflating: /content/image_dataset/healthy/0427.jpg
#   inflating: /content/image_dataset/healthy/0428.jpg
#   inflating: /content/image_dataset/healthy/0429.jpg
#   inflating: /content/image_dataset/healthy/0430.jpg
#   inflating: /content/image_dataset/healthy/0431.jpg
#   inflating: /content/image_dataset/healthy/0432.jpg
#   inflating: /content/image_dataset/healthy/0433.jpg
#   inflating: /content/image_dataset/healthy/0434.jpg
#   inflating: /content/image_dataset/healthy/0435.jpg
#   inflating: /content/image_dataset/healthy/0436.jpg
#   inflating: /content/image_dataset/healthy/0437.jpg
#   inflating: /content/image_dataset/healthy/0438.jpg
#   inflating: /content/image_dataset/healthy/0439.jpg
#   inflating: /content/image_dataset/healthy/0440.jpg
#   inflating: /content/image_dataset/healthy/0441.jpg
#   inflating: /content/image_dataset/healthy/0442.jpg
#   inflating: /content/image_dataset/healthy/0443.jpg
#   inflating: /content/image_dataset/healthy/0444.jpg
#   inflating: /content/image_dataset/healthy/0445.jpg
#   inflating: /content/image_dataset/healthy/0446.jpg
#   inflating: /content/image_dataset/healthy/0447.jpg
#   inflating: /content/image_dataset/healthy/0448.jpg
#   inflating: /content/image_dataset/healthy/0449.jpg
#   inflating: /content/image_dataset/healthy/0450.jpg
#   inflating: /content/image_dataset/healthy/0451.jpg
#   inflating: /content/image_dataset/healthy/0452.jpg
#   inflating: /content/image_dataset/healthy/0453.jpg
#   inflating: /content/image_dataset/healthy/0454.jpg
#   inflating: /content/image_dataset/healthy/0455.jpg
#   inflating: /content/image_dataset/healthy/0456.jpg
#   inflating: /content/image_dataset/healthy/0457.jpg
#   inflating: /content/image_dataset/healthy/0458.jpg
#   inflating: /content/image_dataset/healthy/0459.jpg
#   inflating: /content/image_dataset/healthy/0460.jpg
#   inflating: /content/image_dataset/healthy/0461.jpg
#   inflating: /content/image_dataset/healthy/0462.jpg
#   inflating: /content/image_dataset/healthy/0463.jpg
#   inflating: /content/image_dataset/healthy/0464.jpg
#   inflating: /content/image_dataset/healthy/0465.jpg
#   inflating: /content/image_dataset/healthy/0466.jpg
#   inflating: /content/image_dataset/healthy/0467.jpg
#   inflating: /content/image_dataset/healthy/0468.jpg
#   inflating: /content/image_dataset/healthy/0469.jpg
#   inflating: /content/image_dataset/healthy/0470.jpg
#   inflating: /content/image_dataset/healthy/0471.jpg
#   inflating: /content/image_dataset/healthy/0472.jpg
#   inflating: /content/image_dataset/healthy/0473.jpg
#   inflating: /content/image_dataset/healthy/0474.jpg
#   inflating: /content/image_dataset/healthy/0475.jpg
#   inflating: /content/image_dataset/healthy/0476.jpg
#   inflating: /content/image_dataset/healthy/0477.jpg
#   inflating: /content/image_dataset/healthy/0478.jpg
#   inflating: /content/image_dataset/healthy/0479.jpg
#   inflating: /content/image_dataset/healthy/0480.jpg
#   inflating: /content/image_dataset/healthy/0481.jpg
#   inflating: /content/image_dataset/healthy/0482.jpg
#   inflating: /content/image_dataset/healthy/0483.jpg
#   inflating: /content/image_dataset/healthy/0484.jpg
#   inflating: /content/image_dataset/healthy/0485.jpg
#   inflating: /content/image_dataset/healthy/0486.jpg
#   inflating: /content/image_dataset/healthy/0487.jpg
#   inflating: /content/image_dataset/healthy/0488.jpg
#   inflating: /content/image_dataset/healthy/0489.jpg
#   inflating: /content/image_dataset/healthy/0490.jpg
#   inflating: /content/image_dataset/healthy/0491.jpg
#   inflating: /content/image_dataset/healthy/0492.jpg
#   inflating: /content/image_dataset/healthy/0493.jpg
#   inflating: /content/image_dataset/healthy/0494.jpg
#   inflating: /content/image_dataset/healthy/0495.jpg
#   inflating: /content/image_dataset/healthy/0496.jpg
#   inflating: /content/image_dataset/healthy/0497.jpg
#   inflating: /content/image_dataset/healthy/0498.jpg
#   inflating: /content/image_dataset/healthy/0499.jpg
#   inflating: /content/image_dataset/healthy/0500.jpg
#   inflating: /content/image_dataset/healthy/0501.jpg
#   inflating: /content/image_dataset/healthy/0502.jpg
#   inflating: /content/image_dataset/healthy/0503.jpg
#   inflating: /content/image_dataset/healthy/0504.jpg
#   inflating: /content/image_dataset/healthy/0505.jpg
#   inflating: /content/image_dataset/healthy/0506.jpg
#   inflating: /content/image_dataset/healthy/0507.jpg
#   inflating: /content/image_dataset/healthy/0508.jpg
#   inflating: /content/image_dataset/healthy/0509.jpg
#   inflating: /content/image_dataset/healthy/0510.jpg
#   inflating: /content/image_dataset/healthy/0511.jpg
#   inflating: /content/image_dataset/healthy/0512.jpg
#   inflating: /content/image_dataset/healthy/0513.jpg
#   inflating: /content/image_dataset/healthy/0514.jpg
#   inflating: /content/image_dataset/healthy/0515.jpg
#   inflating: /content/image_dataset/healthy/0516.jpg
#   inflating: /content/image_dataset/healthy/0517.jpg
#   inflating: /content/image_dataset/healthy/0518.jpg
#   inflating: /content/image_dataset/healthy/0519.jpg
#   inflating: /content/image_dataset/healthy/0520.jpg
#   inflating: /content/image_dataset/healthy/0521.jpg
#   inflating: /content/image_dataset/healthy/0522.jpg
#   inflating: /content/image_dataset/healthy/0523.jpg
#   inflating: /content/image_dataset/healthy/0524.jpg
#   inflating: /content/image_dataset/healthy/0525.jpg
#   inflating: /content/image_dataset/healthy/0526.jpg
#   inflating: /content/image_dataset/healthy/0527.jpg
#   inflating: /content/image_dataset/healthy/0528.jpg
#   inflating: /content/image_dataset/healthy/0529.jpg
#   inflating: /content/image_dataset/healthy/0530.jpg
#   inflating: /content/image_dataset/healthy/0531.jpg
#   inflating: /content/image_dataset/healthy/0532.jpg
#   inflating: /content/image_dataset/healthy/0533.jpg
#   inflating: /content/image_dataset/healthy/0534.jpg
#   inflating: /content/image_dataset/healthy/0535.jpg
#   inflating: /content/image_dataset/healthy/0536.jpg
#   inflating: /content/image_dataset/healthy/0537.jpg
#   inflating: /content/image_dataset/healthy/0538.jpg
#   inflating: /content/image_dataset/healthy/0539.jpg
#   inflating: /content/image_dataset/healthy/0540.jpg
#   inflating: /content/image_dataset/healthy/0541.jpg
#   inflating: /content/image_dataset/healthy/0542.jpg
#   inflating: /content/image_dataset/healthy/0543.jpg
#   inflating: /content/image_dataset/healthy/0544.jpg
#   inflating: /content/image_dataset/healthy/0545.jpg
#   inflating: /content/image_dataset/healthy/0546.jpg
#   inflating: /content/image_dataset/healthy/0547.jpg
#   inflating: /content/image_dataset/healthy/0548.jpg
#   inflating: /content/image_dataset/healthy/0549.jpg
#   inflating: /content/image_dataset/healthy/0550.jpg
#   inflating: /content/image_dataset/healthy/0551.jpg
#   inflating: /content/image_dataset/healthy/0552.jpg
#   inflating: /content/image_dataset/healthy/0553.jpg
#   inflating: /content/image_dataset/healthy/0554.jpg
#   inflating: /content/image_dataset/healthy/0555.jpg
#   inflating: /content/image_dataset/healthy/0556.jpg
#   inflating: /content/image_dataset/healthy/0557.jpg
#   inflating: /content/image_dataset/healthy/0558.jpg
#   inflating: /content/image_dataset/healthy/0559.jpg
#   inflating: /content/image_dataset/healthy/0560.jpg
#   inflating: /content/image_dataset/healthy/0561.jpg
#   inflating: /content/image_dataset/healthy/0562.jpg
#   inflating: /content/image_dataset/healthy/0563.jpg
#   inflating: /content/image_dataset/healthy/0564.jpg
#   inflating: /content/image_dataset/healthy/0565.jpg
#   inflating: /content/image_dataset/healthy/0566.jpg
#   inflating: /content/image_dataset/healthy/0567.jpg
#   inflating: /content/image_dataset/healthy/0568.jpg
#   inflating: /content/image_dataset/healthy/0569.jpg
#   inflating: /content/image_dataset/healthy/0570.jpg
#   inflating: /content/image_dataset/healthy/0571.jpg
#   inflating: /content/image_dataset/healthy/0572.jpg
#   inflating: /content/image_dataset/healthy/0573.jpg
#   inflating: /content/image_dataset/healthy/0574.jpg
#   inflating: /content/image_dataset/healthy/0575.jpg
#   inflating: /content/image_dataset/healthy/0576.jpg
#   inflating: /content/image_dataset/healthy/0577.jpg
#   inflating: /content/image_dataset/healthy/0578.jpg
#   inflating: /content/image_dataset/healthy/0579.jpg
#   inflating: /content/image_dataset/healthy/0580.jpg
#   inflating: /content/image_dataset/healthy/0581.jpg
#   inflating: /content/image_dataset/healthy/0582.jpg
#   inflating: /content/image_dataset/healthy/0583.jpg
#   inflating: /content/image_dataset/healthy/0584.jpg
#   inflating: /content/image_dataset/healthy/0585.jpg
#   inflating: /content/image_dataset/healthy/0586.jpg
#   inflating: /content/image_dataset/healthy/0587.jpg
#   inflating: /content/image_dataset/healthy/0588.jpg
#   inflating: /content/image_dataset/healthy/0589.jpg
#   inflating: /content/image_dataset/healthy/0590.jpg
#   inflating: /content/image_dataset/healthy/0591.jpg
#   inflating: /content/image_dataset/healthy/0592.jpg
#   inflating: /content/image_dataset/healthy/0593.jpg
#   inflating: /content/image_dataset/healthy/0594.jpg
#   inflating: /content/image_dataset/healthy/0595.jpg
#   inflating: /content/image_dataset/healthy/0596.jpg
#   inflating: /content/image_dataset/healthy/0597.jpg
#   inflating: /content/image_dataset/healthy/0598.jpg
#   inflating: /content/image_dataset/healthy/0599.jpg
#   inflating: /content/image_dataset/healthy/0600.jpg
#   inflating: /content/image_dataset/healthy/0601.jpg
#   inflating: /content/image_dataset/healthy/0602.jpg
#   inflating: /content/image_dataset/healthy/0603.jpg
#   inflating: /content/image_dataset/healthy/0604.jpg
#   inflating: /content/image_dataset/healthy/0605.jpg
#   inflating: /content/image_dataset/healthy/0606.jpg
#   inflating: /content/image_dataset/healthy/0607.jpg
#   inflating: /content/image_dataset/healthy/0608.jpg
#   inflating: /content/image_dataset/healthy/0609.jpg
#   inflating: /content/image_dataset/healthy/0610.jpg
#   inflating: /content/image_dataset/healthy/0611.jpg
#   inflating: /content/image_dataset/healthy/0612.jpg
#   inflating: /content/image_dataset/healthy/0613.jpg
#   inflating: /content/image_dataset/healthy/0614.jpg
#   inflating: /content/image_dataset/healthy/0615.jpg
#   inflating: /content/image_dataset/healthy/0616.jpg
#   inflating: /content/image_dataset/healthy/0617.jpg
#   inflating: /content/image_dataset/healthy/0618.jpg
#   inflating: /content/image_dataset/healthy/0619.jpg
#   inflating: /content/image_dataset/healthy/0620.jpg
#   inflating: /content/image_dataset/healthy/0621.jpg
#   inflating: /content/image_dataset/healthy/0622.jpg
#   inflating: /content/image_dataset/healthy/0623.jpg
#   inflating: /content/image_dataset/healthy/0624.jpg
#   inflating: /content/image_dataset/healthy/0625.jpg
#   inflating: /content/image_dataset/healthy/0626.jpg
#   inflating: /content/image_dataset/healthy/0627.jpg
#   inflating: /content/image_dataset/healthy/0628.jpg
#   inflating: /content/image_dataset/healthy/0629.jpg
#   inflating: /content/image_dataset/healthy/0630.jpg
#   inflating: /content/image_dataset/healthy/0631.jpg
#   inflating: /content/image_dataset/healthy/0632.jpg
#   inflating: /content/image_dataset/healthy/0633.jpg
#   inflating: /content/image_dataset/healthy/0634.jpg
#   inflating: /content/image_dataset/healthy/0635.jpg
#   inflating: /content/image_dataset/healthy/0636.jpg
#   inflating: /content/image_dataset/healthy/0637.jpg
#   inflating: /content/image_dataset/healthy/0638.jpg
#   inflating: /content/image_dataset/healthy/0639.jpg
#   inflating: /content/image_dataset/healthy/0640.jpg
#   inflating: /content/image_dataset/healthy/0641.jpg
#   inflating: /content/image_dataset/healthy/0642.jpg
#   inflating: /content/image_dataset/healthy/0643.jpg
#   inflating: /content/image_dataset/healthy/0644.jpg
#   inflating: /content/image_dataset/healthy/0645.jpg
#   inflating: /content/image_dataset/healthy/0646.jpg
#   inflating: /content/image_dataset/healthy/0647.jpg
#   inflating: /content/image_dataset/healthy/0648.jpg
#   inflating: /content/image_dataset/healthy/0649.jpg
#   inflating: /content/image_dataset/healthy/0650.jpg
#   inflating: /content/image_dataset/healthy/0651.jpg
#   inflating: /content/image_dataset/healthy/0652.jpg
#   inflating: /content/image_dataset/healthy/0653.jpg
#   inflating: /content/image_dataset/healthy/0654.jpg
#   inflating: /content/image_dataset/healthy/0655.jpg
#   inflating: /content/image_dataset/healthy/0656.jpg
#   inflating: /content/image_dataset/healthy/0657.jpg
#   inflating: /content/image_dataset/healthy/0658.jpg
#   inflating: /content/image_dataset/healthy/0659.jpg
#   inflating: /content/image_dataset/healthy/0660.jpg
#   inflating: /content/image_dataset/healthy/0661.jpg
#   inflating: /content/image_dataset/healthy/0662.jpg
#   inflating: /content/image_dataset/healthy/0663.jpg
#   inflating: /content/image_dataset/healthy/0664.jpg
#   inflating: /content/image_dataset/healthy/0665.jpg
#   inflating: /content/image_dataset/healthy/0666.jpg
#   inflating: /content/image_dataset/healthy/0667.jpg
#   inflating: /content/image_dataset/healthy/0668.jpg
#   inflating: /content/image_dataset/healthy/0669.jpg
#   inflating: /content/image_dataset/healthy/0670.jpg
#   inflating: /content/image_dataset/healthy/0671.jpg
#   inflating: /content/image_dataset/healthy/0672.jpg
#   inflating: /content/image_dataset/healthy/0673.jpg
#   inflating: /content/image_dataset/healthy/0674.jpg
#   inflating: /content/image_dataset/healthy/0675.jpg
#   inflating: /content/image_dataset/healthy/0676.jpg
#   inflating: /content/image_dataset/healthy/0677.jpg
#   inflating: /content/image_dataset/healthy/0678.jpg
#   inflating: /content/image_dataset/healthy/0679.jpg
#   inflating: /content/image_dataset/healthy/0680.jpg
#   inflating: /content/image_dataset/healthy/0681.jpg
#   inflating: /content/image_dataset/healthy/0682.jpg
#   inflating: /content/image_dataset/healthy/0683.jpg
#   inflating: /content/image_dataset/healthy/0684.jpg
#   inflating: /content/image_dataset/healthy/0685.jpg
#   inflating: /content/image_dataset/healthy/0686.jpg
#   inflating: /content/image_dataset/healthy/0687.jpg
#   inflating: /content/image_dataset/healthy/0688.jpg
#   inflating: /content/image_dataset/healthy/0689.jpg
#   inflating: /content/image_dataset/healthy/0690.jpg
#   inflating: /content/image_dataset/healthy/0691.jpg
#   inflating: /content/image_dataset/healthy/0692.jpg
#   inflating: /content/image_dataset/healthy/0693.jpg
#   inflating: /content/image_dataset/healthy/0694.jpg
#   inflating: /content/image_dataset/healthy/0695.jpg
#   inflating: /content/image_dataset/healthy/0696.jpg
#   inflating: /content/image_dataset/healthy/0697.jpg
#   inflating: /content/image_dataset/healthy/0698.jpg
#   inflating: /content/image_dataset/healthy/0699.jpg
#   inflating: /content/image_dataset/healthy/0700.jpg
#   inflating: /content/image_dataset/healthy/0701.jpg
#   inflating: /content/image_dataset/healthy/0702.jpg
#   inflating: /content/image_dataset/healthy/0703.jpg
#   inflating: /content/image_dataset/healthy/0704.jpg
#   inflating: /content/image_dataset/healthy/0705.jpg
#   inflating: /content/image_dataset/healthy/0706.jpg
#   inflating: /content/image_dataset/healthy/0707.jpg
#   inflating: /content/image_dataset/healthy/0708.jpg
#   inflating: /content/image_dataset/healthy/0709.jpg
#   inflating: /content/image_dataset/healthy/0710.jpg
#   inflating: /content/image_dataset/healthy/0711.jpg
#   inflating: /content/image_dataset/healthy/0712.jpg
#   inflating: /content/image_dataset/healthy/0713.jpg
#   inflating: /content/image_dataset/healthy/0714.jpg
#   inflating: /content/image_dataset/healthy/0715.jpg
#   inflating: /content/image_dataset/healthy/0716.jpg
#   inflating: /content/image_dataset/healthy/0717.jpg
#   inflating: /content/image_dataset/healthy/0718.jpg
#   inflating: /content/image_dataset/healthy/0719.jpg
#   inflating: /content/image_dataset/healthy/0720.jpg
#   inflating: /content/image_dataset/healthy/0721.jpg
#   inflating: /content/image_dataset/healthy/0722.jpg
#   inflating: /content/image_dataset/healthy/0723.jpg
#   inflating: /content/image_dataset/healthy/0724.jpg
#   inflating: /content/image_dataset/healthy/0725.jpg
#   inflating: /content/image_dataset/healthy/0726.jpg
#   inflating: /content/image_dataset/healthy/0727.jpg
#   inflating: /content/image_dataset/healthy/0728.jpg
#   inflating: /content/image_dataset/healthy/0729.jpg
#   inflating: /content/image_dataset/healthy/0730.jpg
#   inflating: /content/image_dataset/healthy/0731.jpg
#   inflating: /content/image_dataset/healthy/0732.jpg
#   inflating: /content/image_dataset/healthy/0733.jpg
#   inflating: /content/image_dataset/healthy/0734.jpg
#   inflating: /content/image_dataset/healthy/0735.jpg
#   inflating: /content/image_dataset/healthy/0736.jpg
#   inflating: /content/image_dataset/healthy/0737.jpg
#   inflating: /content/image_dataset/healthy/0738.jpg
#   inflating: /content/image_dataset/healthy/0739.jpg
#   inflating: /content/image_dataset/healthy/0740.jpg
#   inflating: /content/image_dataset/healthy/0741.jpg
#   inflating: /content/image_dataset/healthy/0742.jpg
#   inflating: /content/image_dataset/healthy/0743.jpg
#   inflating: /content/image_dataset/healthy/0744.jpg
#   inflating: /content/image_dataset/healthy/0745.jpg
#   inflating: /content/image_dataset/healthy/0746.jpg
#   inflating: /content/image_dataset/healthy/0747.jpg
#   inflating: /content/image_dataset/healthy/0748.jpg
#   inflating: /content/image_dataset/healthy/0749.jpg
#   inflating: /content/image_dataset/healthy/0750.jpg
#   inflating: /content/image_dataset/healthy/0751.jpg
#   inflating: /content/image_dataset/healthy/0752.jpg
#   inflating: /content/image_dataset/healthy/0753.jpg
#   inflating: /content/image_dataset/healthy/0754.jpg
#   inflating: /content/image_dataset/healthy/0755.jpg
#   inflating: /content/image_dataset/healthy/0756.jpg
#   inflating: /content/image_dataset/healthy/0757.jpg
#   inflating: /content/image_dataset/healthy/0758.jpg
#   inflating: /content/image_dataset/healthy/0759.jpg
#   inflating: /content/image_dataset/healthy/0760.jpg
#   inflating: /content/image_dataset/healthy/0761.jpg
#   inflating: /content/image_dataset/healthy/0762.jpg
#   inflating: /content/image_dataset/healthy/0763.jpg
#   inflating: /content/image_dataset/healthy/0764.jpg
#   inflating: /content/image_dataset/healthy/0765.jpg
#   inflating: /content/image_dataset/healthy/0766.jpg
#   inflating: /content/image_dataset/healthy/0767.jpg
#   inflating: /content/image_dataset/healthy/0768.jpg
#   inflating: /content/image_dataset/healthy/0769.jpg
#   inflating: /content/image_dataset/healthy/0770.jpg
#   inflating: /content/image_dataset/healthy/0771.jpg
#   inflating: /content/image_dataset/healthy/0772.jpg
#   inflating: /content/image_dataset/healthy/0773.jpg
#   inflating: /content/image_dataset/healthy/0774.jpg
#   inflating: /content/image_dataset/healthy/0775.jpg
#   inflating: /content/image_dataset/healthy/0776.jpg
#   inflating: /content/image_dataset/healthy/0777.jpg
#   inflating: /content/image_dataset/healthy/0778.jpg
#   inflating: /content/image_dataset/healthy/0779.jpg
#   inflating: /content/image_dataset/healthy/0780.jpg
#   inflating: /content/image_dataset/healthy/0781.jpg
#   inflating: /content/image_dataset/healthy/0782.jpg
#   inflating: /content/image_dataset/healthy/0783.jpg
#   inflating: /content/image_dataset/healthy/0784.jpg
#   inflating: /content/image_dataset/healthy/0785.jpg
#   inflating: /content/image_dataset/healthy/0786.jpg
#   inflating: /content/image_dataset/healthy/0787.jpg
#   inflating: /content/image_dataset/healthy/0788.jpg
#   inflating: /content/image_dataset/healthy/0789.jpg
#   inflating: /content/image_dataset/healthy/0790.jpg
#   inflating: /content/image_dataset/healthy/0791.jpg
#   inflating: /content/image_dataset/healthy/0792.jpg
#   inflating: /content/image_dataset/healthy/0793.jpg
#   inflating: /content/image_dataset/healthy/0794.jpg
#   inflating: /content/image_dataset/healthy/0795.jpg
#   inflating: /content/image_dataset/healthy/0796.jpg
#   inflating: /content/image_dataset/healthy/0797.jpg
#   inflating: /content/image_dataset/healthy/0798.jpg
#   inflating: /content/image_dataset/healthy/0799.jpg
#   inflating: /content/image_dataset/healthy/0800.jpg
#   inflating: /content/image_dataset/healthy/0801.jpg
#   inflating: /content/image_dataset/healthy/0802.jpg
#   inflating: /content/image_dataset/healthy/0803.jpg
#   inflating: /content/image_dataset/healthy/0804.jpg
#   inflating: /content/image_dataset/healthy/0805.jpg
#   inflating: /content/image_dataset/healthy/0806.jpg
#   inflating: /content/image_dataset/healthy/0807.jpg
#   inflating: /content/image_dataset/healthy/0808.jpg
#   inflating: /content/image_dataset/healthy/0809.jpg
#   inflating: /content/image_dataset/healthy/0810.jpg
#   inflating: /content/image_dataset/healthy/0811.jpg
#   inflating: /content/image_dataset/healthy/0812.jpg
#   inflating: /content/image_dataset/healthy/0813.jpg
#   inflating: /content/image_dataset/healthy/0814.jpg
#   inflating: /content/image_dataset/healthy/0815.jpg
#   inflating: /content/image_dataset/healthy/0816.jpg
#   inflating: /content/image_dataset/healthy/0817.jpg
#   inflating: /content/image_dataset/healthy/0818.jpg
#   inflating: /content/image_dataset/healthy/0819.jpg
#   inflating: /content/image_dataset/healthy/0820.jpg
#   inflating: /content/image_dataset/healthy/0821.jpg
#   inflating: /content/image_dataset/healthy/0822.jpg
#   inflating: /content/image_dataset/healthy/0823.jpg
#   inflating: /content/image_dataset/healthy/0824.jpg
#   inflating: /content/image_dataset/healthy/0825.jpg
#   inflating: /content/image_dataset/healthy/0826.jpg
#   inflating: /content/image_dataset/healthy/0827.jpg
#   inflating: /content/image_dataset/healthy/0828.jpg
#   inflating: /content/image_dataset/healthy/0829.jpg
#   inflating: /content/image_dataset/healthy/0830.jpg
#   inflating: /content/image_dataset/healthy/0831.jpg
#   inflating: /content/image_dataset/healthy/0832.jpg
#   inflating: /content/image_dataset/healthy/0833.jpg
#   inflating: /content/image_dataset/healthy/0834.jpg
#   inflating: /content/image_dataset/healthy/0835.jpg
#   inflating: /content/image_dataset/healthy/0836.jpg
#   inflating: /content/image_dataset/healthy/0837.jpg
#   inflating: /content/image_dataset/healthy/0838.jpg
#   inflating: /content/image_dataset/healthy/0839.jpg
#   inflating: /content/image_dataset/healthy/0840.jpg
#   inflating: /content/image_dataset/healthy/0841.jpg
#   inflating: /content/image_dataset/healthy/0842.jpg
#   inflating: /content/image_dataset/healthy/0843.jpg
#   inflating: /content/image_dataset/healthy/0844.jpg
#   inflating: /content/image_dataset/healthy/0845.jpg
#   inflating: /content/image_dataset/healthy/0846.jpg
#   inflating: /content/image_dataset/healthy/0847.jpg
#   inflating: /content/image_dataset/healthy/0848.jpg
#   inflating: /content/image_dataset/healthy/0849.jpg
#   inflating: /content/image_dataset/healthy/0850.jpg
#   inflating: /content/image_dataset/healthy/0851.jpg
#   inflating: /content/image_dataset/healthy/0852.jpg
#   inflating: /content/image_dataset/healthy/0853.jpg
#   inflating: /content/image_dataset/healthy/0854.jpg
#   inflating: /content/image_dataset/healthy/0855.jpg
#   inflating: /content/image_dataset/healthy/0856.jpg
#   inflating: /content/image_dataset/healthy/0857.jpg
#   inflating: /content/image_dataset/healthy/0858.jpg
#   inflating: /content/image_dataset/healthy/0859.jpg
#   inflating: /content/image_dataset/healthy/0860.jpg
#   inflating: /content/image_dataset/healthy/0861.jpg
#   inflating: /content/image_dataset/healthy/0862.jpg
#   inflating: /content/image_dataset/healthy/0863.jpg
#   inflating: /content/image_dataset/healthy/0864.jpg
#   inflating: /content/image_dataset/healthy/0865.jpg
#   inflating: /content/image_dataset/healthy/0866.jpg
#   inflating: /content/image_dataset/healthy/0867.jpg
#   inflating: /content/image_dataset/healthy/0868.jpg
#   inflating: /content/image_dataset/healthy/0869.jpg
#   inflating: /content/image_dataset/healthy/0870.jpg
#   inflating: /content/image_dataset/healthy/0871.jpg
#   inflating: /content/image_dataset/healthy/0872.jpg
#   inflating: /content/image_dataset/healthy/0873.jpg
#   inflating: /content/image_dataset/healthy/0874.jpg
#   inflating: /content/image_dataset/healthy/0875.jpg
#   inflating: /content/image_dataset/healthy/0876.jpg
#   inflating: /content/image_dataset/healthy/0877.jpg
#   inflating: /content/image_dataset/healthy/0878.jpg
#   inflating: /content/image_dataset/healthy/0879.jpg
#   inflating: /content/image_dataset/healthy/0880.jpg
#   inflating: /content/image_dataset/healthy/0881.jpg
#   inflating: /content/image_dataset/healthy/0882.jpg
#   inflating: /content/image_dataset/healthy/0883.jpg
#   inflating: /content/image_dataset/healthy/0884.jpg
#   inflating: /content/image_dataset/healthy/0885.jpg
#   inflating: /content/image_dataset/healthy/0886.jpg
#   inflating: /content/image_dataset/healthy/0887.jpg
#   inflating: /content/image_dataset/healthy/0888.jpg
#   inflating: /content/image_dataset/healthy/0889.jpg
#   inflating: /content/image_dataset/healthy/0890.jpg
#   inflating: /content/image_dataset/healthy/0891.jpg
#   inflating: /content/image_dataset/healthy/0892.jpg
#   inflating: /content/image_dataset/healthy/0893.jpg
#   inflating: /content/image_dataset/healthy/0894.jpg
#   inflating: /content/image_dataset/healthy/0895.jpg
#   inflating: /content/image_dataset/healthy/0896.jpg
#   inflating: /content/image_dataset/healthy/0897.jpg
#   inflating: /content/image_dataset/healthy/0898.jpg
#   inflating: /content/image_dataset/healthy/0899.jpg
#   inflating: /content/image_dataset/healthy/0900.jpg
#   inflating: /content/image_dataset/healthy/0901.jpg
#   inflating: /content/image_dataset/healthy/0902.jpg
#   inflating: /content/image_dataset/healthy/0903.jpg
#   inflating: /content/image_dataset/healthy/0904.jpg
#   inflating: /content/image_dataset/healthy/0905.jpg
#   inflating: /content/image_dataset/healthy/0906.jpg
#   inflating: /content/image_dataset/healthy/0907.jpg
#   inflating: /content/image_dataset/healthy/0908.jpg
#   inflating: /content/image_dataset/healthy/0909.jpg
#   inflating: /content/image_dataset/healthy/0910.jpg
#   inflating: /content/image_dataset/healthy/0911.jpg
#   inflating: /content/image_dataset/healthy/0912.jpg
#   inflating: /content/image_dataset/healthy/0913.jpg
#   inflating: /content/image_dataset/healthy/0914.jpg
#   inflating: /content/image_dataset/healthy/0915.jpg
#   inflating: /content/image_dataset/healthy/0916.jpg
#   inflating: /content/image_dataset/healthy/0917.jpg
#   inflating: /content/image_dataset/healthy/0918.jpg
#   inflating: /content/image_dataset/healthy/0919.jpg
#   inflating: /content/image_dataset/healthy/0920.jpg
#   inflating: /content/image_dataset/healthy/0921.jpg
#   inflating: /content/image_dataset/healthy/0922.jpg
#   inflating: /content/image_dataset/healthy/0923.jpg
#   inflating: /content/image_dataset/healthy/0924.jpg
#   inflating: /content/image_dataset/healthy/0925.jpg
#   inflating: /content/image_dataset/healthy/0926.jpg
#   inflating: /content/image_dataset/healthy/0927.jpg
#   inflating: /content/image_dataset/healthy/0928.jpg
#   inflating: /content/image_dataset/healthy/0929.jpg
#   inflating: /content/image_dataset/healthy/0930.jpg
#   inflating: /content/image_dataset/healthy/0931.jpg
#   inflating: /content/image_dataset/healthy/0932.jpg
#   inflating: /content/image_dataset/healthy/0933.jpg
#   inflating: /content/image_dataset/healthy/0934.jpg
#   inflating: /content/image_dataset/healthy/0935.jpg
#   inflating: /content/image_dataset/healthy/0936.jpg
#   inflating: /content/image_dataset/healthy/0937.jpg
#   inflating: /content/image_dataset/healthy/0938.jpg
#   inflating: /content/image_dataset/healthy/0939.jpg
#   inflating: /content/image_dataset/healthy/0940.jpg
#   inflating: /content/image_dataset/healthy/0941.jpg
#   inflating: /content/image_dataset/healthy/0942.jpg
#   inflating: /content/image_dataset/healthy/0943.jpg
#   inflating: /content/image_dataset/healthy/0944.jpg
#   inflating: /content/image_dataset/healthy/0945.jpg
#   inflating: /content/image_dataset/healthy/0946.jpg
#   inflating: /content/image_dataset/healthy/0947.jpg
#   inflating: /content/image_dataset/healthy/0948.jpg
#   inflating: /content/image_dataset/healthy/0949.jpg
#   inflating: /content/image_dataset/healthy/0950.jpg
#   inflating: /content/image_dataset/healthy/0951.jpg
#   inflating: /content/image_dataset/healthy/0952.jpg
#   inflating: /content/image_dataset/healthy/0953.jpg
#   inflating: /content/image_dataset/healthy/0954.jpg
#   inflating: /content/image_dataset/healthy/0955.jpg
#   inflating: /content/image_dataset/healthy/0956.jpg
#   inflating: /content/image_dataset/healthy/0957.jpg
#   inflating: /content/image_dataset/healthy/0958.jpg
#   inflating: /content/image_dataset/healthy/0959.jpg
#   inflating: /content/image_dataset/healthy/0960.jpg
#   inflating: /content/image_dataset/healthy/0961.jpg
#   inflating: /content/image_dataset/healthy/0962.jpg
#   inflating: /content/image_dataset/healthy/0963.jpg
#   inflating: /content/image_dataset/healthy/0964.jpg
#   inflating: /content/image_dataset/healthy/0965.jpg
#   inflating: /content/image_dataset/healthy/0966.jpg
#   inflating: /content/image_dataset/healthy/0967.jpg
#   inflating: /content/image_dataset/healthy/0968.jpg
#   inflating: /content/image_dataset/healthy/0969.jpg
#   inflating: /content/image_dataset/healthy/0970.jpg
#   inflating: /content/image_dataset/healthy/0971.jpg
#   inflating: /content/image_dataset/healthy/0972.jpg
#   inflating: /content/image_dataset/healthy/0973.jpg
#   inflating: /content/image_dataset/healthy/0974.jpg
#   inflating: /content/image_dataset/healthy/0975.jpg
#   inflating: /content/image_dataset/healthy/0976.jpg
#   inflating: /content/image_dataset/healthy/0977.jpg
#   inflating: /content/image_dataset/healthy/0978.jpg
#   inflating: /content/image_dataset/healthy/0979.jpg
#   inflating: /content/image_dataset/healthy/0980.jpg
#   inflating: /content/image_dataset/healthy/0981.jpg
#   inflating: /content/image_dataset/healthy/0982.jpg
#   inflating: /content/image_dataset/healthy/0983.jpg
#   inflating: /content/image_dataset/healthy/0984.jpg
#   inflating: /content/image_dataset/healthy/0985.jpg
#   inflating: /content/image_dataset/healthy/0986.jpg
#   inflating: /content/image_dataset/healthy/0987.jpg
#   inflating: /content/image_dataset/healthy/0988.jpg
#   inflating: /content/image_dataset/healthy/0989.jpg
#   inflating: /content/image_dataset/healthy/0990.jpg
#   inflating: /content/image_dataset/healthy/0991.jpg
#   inflating: /content/image_dataset/healthy/0992.jpg
#   inflating: /content/image_dataset/healthy/0993.jpg
#   inflating: /content/image_dataset/healthy/0994.jpg
#   inflating: /content/image_dataset/healthy/0995.jpg
#   inflating: /content/image_dataset/healthy/0996.jpg
#   inflating: /content/image_dataset/healthy/0997.jpg
#   inflating: /content/image_dataset/healthy/0998.jpg
#   inflating: /content/image_dataset/healthy/0999.jpg
#   inflating: /content/image_dataset/healthy/1000.jpg
#   inflating: /content/image_dataset/healthy/1001.jpg
#   inflating: /content/image_dataset/healthy/1002.jpg
#   inflating: /content/image_dataset/healthy/1003.jpg
#   inflating: /content/image_dataset/healthy/1004.jpg
#   inflating: /content/image_dataset/healthy/1005.jpg
#   inflating: /content/image_dataset/healthy/1006.jpg
#   inflating: /content/image_dataset/healthy/1007.jpg
#   inflating: /content/image_dataset/healthy/1008.jpg
#   inflating: /content/image_dataset/healthy/1009.jpg
#   inflating: /content/image_dataset/healthy/1010.jpg
#   inflating: /content/image_dataset/healthy/1011.jpg
#   inflating: /content/image_dataset/healthy/1012.jpg
#   inflating: /content/image_dataset/healthy/1013.jpg
#   inflating: /content/image_dataset/healthy/1014.jpg
#   inflating: /content/image_dataset/healthy/1015.jpg
#   inflating: /content/image_dataset/healthy/1016.jpg
#   inflating: /content/image_dataset/healthy/1017.jpg
#   inflating: /content/image_dataset/healthy/1018.jpg
#   inflating: /content/image_dataset/healthy/1019.jpg
#   inflating: /content/image_dataset/healthy/1020.jpg
#   inflating: /content/image_dataset/healthy/1021.jpg
#   inflating: /content/image_dataset/healthy/1022.jpg
#   inflating: /content/image_dataset/healthy/1023.jpg
#   inflating: /content/image_dataset/healthy/1024.jpg
#   inflating: /content/image_dataset/healthy/1025.jpg
#   inflating: /content/image_dataset/healthy/1026.jpg
#   inflating: /content/image_dataset/healthy/1027.jpg
#   inflating: /content/image_dataset/healthy/1028.jpg
#   inflating: /content/image_dataset/healthy/1029.jpg
#   inflating: /content/image_dataset/healthy/1030.jpg
#   inflating: /content/image_dataset/healthy/1031.jpg
#   inflating: /content/image_dataset/healthy/1032.jpg
#   inflating: /content/image_dataset/healthy/1033.jpg
#   inflating: /content/image_dataset/healthy/1034.jpg
#   inflating: /content/image_dataset/healthy/1035.jpg
#   inflating: /content/image_dataset/healthy/1036.jpg
#   inflating: /content/image_dataset/healthy/1037.jpg
#   inflating: /content/image_dataset/healthy/1038.jpg
#   inflating: /content/image_dataset/healthy/1039.jpg
#   inflating: /content/image_dataset/healthy/1040.jpg
#   inflating: /content/image_dataset/healthy/1041.jpg
#   inflating: /content/image_dataset/healthy/1042.jpg
#   inflating: /content/image_dataset/healthy/1043.jpg
#   inflating: /content/image_dataset/healthy/1044.jpg
#   inflating: /content/image_dataset/healthy/1045.jpg
#   inflating: /content/image_dataset/healthy/1046.jpg
#   inflating: /content/image_dataset/healthy/1047.jpg
#   inflating: /content/image_dataset/healthy/1048.jpg
#   inflating: /content/image_dataset/healthy/1049.jpg
#   inflating: /content/image_dataset/healthy/1050.jpg
#   inflating: /content/image_dataset/healthy/1051.jpg
#   inflating: /content/image_dataset/healthy/1052.jpg
#   inflating: /content/image_dataset/healthy/1053.jpg
#   inflating: /content/image_dataset/healthy/1054.jpg
#   inflating: /content/image_dataset/healthy/1055.jpg
#   inflating: /content/image_dataset/healthy/1056.jpg
#   inflating: /content/image_dataset/healthy/1057.jpg
#   inflating: /content/image_dataset/healthy/1058.jpg
#   inflating: /content/image_dataset/healthy/1059.jpg
#   inflating: /content/image_dataset/healthy/1060.jpg
#   inflating: /content/image_dataset/healthy/1061.jpg
#   inflating: /content/image_dataset/healthy/1062.jpg
#   inflating: /content/image_dataset/healthy/1063.jpg
#   inflating: /content/image_dataset/healthy/1064.jpg
#   inflating: /content/image_dataset/healthy/1065.jpg
#   inflating: /content/image_dataset/healthy/1066.jpg
#   inflating: /content/image_dataset/healthy/1067.jpg
#   inflating: /content/image_dataset/healthy/1068.jpg
#   inflating: /content/image_dataset/healthy/1069.jpg
#   inflating: /content/image_dataset/healthy/1070.jpg
#   inflating: /content/image_dataset/healthy/1071.jpg
#   inflating: /content/image_dataset/healthy/1072.jpg
#   inflating: /content/image_dataset/healthy/1073.jpg
#   inflating: /content/image_dataset/healthy/1074.jpg
#   inflating: /content/image_dataset/healthy/1075.jpg
#   inflating: /content/image_dataset/healthy/1076.jpg
#   inflating: /content/image_dataset/healthy/1077.jpg
#   inflating: /content/image_dataset/healthy/1078.jpg
#   inflating: /content/image_dataset/healthy/1079.jpg
#   inflating: /content/image_dataset/healthy/1080.jpg
#   inflating: /content/image_dataset/healthy/1081.jpg
#   inflating: /content/image_dataset/healthy/1082.jpg
#   inflating: /content/image_dataset/healthy/1083.jpg
#   inflating: /content/image_dataset/healthy/1084.jpg
#   inflating: /content/image_dataset/healthy/1085.jpg
#   inflating: /content/image_dataset/healthy/1086.jpg
#   inflating: /content/image_dataset/healthy/1087.jpg
#   inflating: /content/image_dataset/healthy/1088.jpg
#   inflating: /content/image_dataset/healthy/1089.jpg
#   inflating: /content/image_dataset/healthy/1090.jpg
#   inflating: /content/image_dataset/healthy/1091.jpg
#   inflating: /content/image_dataset/healthy/1092.jpg
#   inflating: /content/image_dataset/healthy/1093.jpg
#   inflating: /content/image_dataset/healthy/1094.jpg
#   inflating: /content/image_dataset/healthy/1095.jpg
#   inflating: /content/image_dataset/healthy/1096.jpg
#   inflating: /content/image_dataset/healthy/1097.jpg
#   inflating: /content/image_dataset/healthy/1098.jpg
#   inflating: /content/image_dataset/healthy/1099.jpg
#   inflating: /content/image_dataset/healthy/1100.jpg
#   inflating: /content/image_dataset/healthy/1101.jpg
#   inflating: /content/image_dataset/healthy/1102.jpg
#   inflating: /content/image_dataset/healthy/1103.jpg
#   inflating: /content/image_dataset/healthy/1104.jpg
#   inflating: /content/image_dataset/healthy/1105.jpg
#   inflating: /content/image_dataset/healthy/1106.jpg
#   inflating: /content/image_dataset/healthy/1107.jpg
#   inflating: /content/image_dataset/healthy/1108.jpg
#   inflating: /content/image_dataset/healthy/1109.jpg
#   inflating: /content/image_dataset/healthy/1110.jpg
#   inflating: /content/image_dataset/healthy/1111.jpg
#   inflating: /content/image_dataset/healthy/1112.jpg
#   inflating: /content/image_dataset/healthy/1113.jpg
#   inflating: /content/image_dataset/healthy/1114.jpg
#   inflating: /content/image_dataset/healthy/1115.jpg
#   inflating: /content/image_dataset/healthy/1116.jpg
#   inflating: /content/image_dataset/healthy/1117.jpg
#   inflating: /content/image_dataset/healthy/1118.jpg
#   inflating: /content/image_dataset/healthy/1119.jpg
#   inflating: /content/image_dataset/healthy/1120.jpg
#   inflating: /content/image_dataset/healthy/1121.jpg
#   inflating: /content/image_dataset/healthy/1122.jpg
#   inflating: /content/image_dataset/healthy/1123.jpg
#   inflating: /content/image_dataset/healthy/1124.jpg
#   inflating: /content/image_dataset/healthy/1125.jpg
#   inflating: /content/image_dataset/healthy/1126.jpg
#   inflating: /content/image_dataset/healthy/1127.jpg
#   inflating: /content/image_dataset/healthy/1128.jpg
#   inflating: /content/image_dataset/healthy/1129.jpg
#   inflating: /content/image_dataset/healthy/1130.jpg
#   inflating: /content/image_dataset/healthy/1131.jpg
#   inflating: /content/image_dataset/healthy/1132.jpg
#   inflating: /content/image_dataset/healthy/1133.jpg
#   inflating: /content/image_dataset/healthy/1134.jpg
#   inflating: /content/image_dataset/healthy/1135.jpg
#   inflating: /content/image_dataset/healthy/1136.jpg
#   inflating: /content/image_dataset/healthy/1137.jpg
#   inflating: /content/image_dataset/healthy/1138.jpg
#   inflating: /content/image_dataset/healthy/1139.jpg
#   inflating: /content/image_dataset/healthy/1140.jpg
#   inflating: /content/image_dataset/healthy/1141.jpg
#   inflating: /content/image_dataset/healthy/1142.jpg
#   inflating: /content/image_dataset/healthy/1143.jpg
#   inflating: /content/image_dataset/healthy/1144.jpg
#   inflating: /content/image_dataset/healthy/1145.jpg
#   inflating: /content/image_dataset/healthy/1146.jpg
#   inflating: /content/image_dataset/healthy/1147.jpg
#   inflating: /content/image_dataset/healthy/1148.jpg
#   inflating: /content/image_dataset/healthy/1149.jpg
#   inflating: /content/image_dataset/healthy/1150.jpg
#   inflating: /content/image_dataset/healthy/1151.jpg
#   inflating: /content/image_dataset/healthy/1152.jpg
#   inflating: /content/image_dataset/healthy/1153.jpg
#   inflating: /content/image_dataset/healthy/1154.jpg
#   inflating: /content/image_dataset/healthy/1155.jpg
#   inflating: /content/image_dataset/healthy/1156.jpg
#   inflating: /content/image_dataset/healthy/1157.jpg
#   inflating: /content/image_dataset/healthy/1158.jpg
#   inflating: /content/image_dataset/healthy/1159.jpg
#   inflating: /content/image_dataset/healthy/1160.jpg
#   inflating: /content/image_dataset/healthy/1161.jpg
#   inflating: /content/image_dataset/healthy/1162.jpg
#   inflating: /content/image_dataset/healthy/1163.jpg
#   inflating: /content/image_dataset/healthy/1164.jpg
#   inflating: /content/image_dataset/healthy/1165.jpg
#   inflating: /content/image_dataset/healthy/1166.jpg
#   inflating: /content/image_dataset/healthy/1167.jpg
#   inflating: /content/image_dataset/healthy/1168.jpg
#   inflating: /content/image_dataset/healthy/1169.jpg
#   inflating: /content/image_dataset/healthy/1170.jpg
#   inflating: /content/image_dataset/healthy/1171.jpg
#   inflating: /content/image_dataset/healthy/1172.jpg
#   inflating: /content/image_dataset/healthy/1173.jpg
#   inflating: /content/image_dataset/healthy/1174.jpg
#   inflating: /content/image_dataset/healthy/1175.jpg
#   inflating: /content/image_dataset/healthy/1176.jpg
#   inflating: /content/image_dataset/healthy/1177.jpg
#   inflating: /content/image_dataset/healthy/1178.jpg
#   inflating: /content/image_dataset/healthy/1179.jpg
#   inflating: /content/image_dataset/healthy/1180.jpg
#   inflating: /content/image_dataset/healthy/1181.jpg
#   inflating: /content/image_dataset/healthy/1182.jpg
#   inflating: /content/image_dataset/healthy/1183.jpg
#   inflating: /content/image_dataset/healthy/1184.jpg
#   inflating: /content/image_dataset/healthy/1185.jpg
#   inflating: /content/image_dataset/healthy/1186.jpg
#   inflating: /content/image_dataset/healthy/1187.jpg
#   inflating: /content/image_dataset/healthy/1188.jpg
#   inflating: /content/image_dataset/healthy/1189.jpg
#   inflating: /content/image_dataset/healthy/1190.jpg
#   inflating: /content/image_dataset/healthy/1191.jpg
#   inflating: /content/image_dataset/healthy/1192.jpg
#   inflating: /content/image_dataset/healthy/1193.jpg
#   inflating: /content/image_dataset/healthy/1194.jpg
#   inflating: /content/image_dataset/healthy/1195.jpg
#   inflating: /content/image_dataset/healthy/1196.jpg
#   inflating: /content/image_dataset/healthy/1197.jpg
#   inflating: /content/image_dataset/healthy/1198.jpg
#   inflating: /content/image_dataset/healthy/1199.jpg
#   inflating: /content/image_dataset/healthy/1200.jpg
#   inflating: /content/image_dataset/healthy/1201.jpg
#   inflating: /content/image_dataset/healthy/1202.jpg
#   inflating: /content/image_dataset/healthy/1203.jpg
#   inflating: /content/image_dataset/healthy/1204.jpg
#   inflating: /content/image_dataset/healthy/1205.jpg
#   inflating: /content/image_dataset/healthy/1206.jpg
#   inflating: /content/image_dataset/healthy/1207.jpg
#   inflating: /content/image_dataset/healthy/1208.jpg
#   inflating: /content/image_dataset/healthy/1209.jpg
#   inflating: /content/image_dataset/healthy/1210.jpg
#   inflating: /content/image_dataset/healthy/1211.jpg
#   inflating: /content/image_dataset/healthy/1212.jpg
#   inflating: /content/image_dataset/healthy/1213.jpg
#   inflating: /content/image_dataset/healthy/1214.jpg
#   inflating: /content/image_dataset/healthy/1215.jpg
#   inflating: /content/image_dataset/healthy/1216.jpg
#   inflating: /content/image_dataset/healthy/1217.jpg
#   inflating: /content/image_dataset/healthy/1218.jpg
#   inflating: /content/image_dataset/healthy/1219.jpg
#   inflating: /content/image_dataset/healthy/1220.jpg
#   inflating: /content/image_dataset/healthy/1221.jpg
#   inflating: /content/image_dataset/healthy/1222.jpg
#   inflating: /content/image_dataset/healthy/1223.jpg
#   inflating: /content/image_dataset/healthy/1224.jpg
#   inflating: /content/image_dataset/healthy/1225.jpg
#   inflating: /content/image_dataset/healthy/1226.jpg
#   inflating: /content/image_dataset/healthy/1227.jpg
#   inflating: /content/image_dataset/healthy/1228.jpg
#   inflating: /content/image_dataset/healthy/1229.jpg
#   inflating: /content/image_dataset/healthy/1230.jpg
#   inflating: /content/image_dataset/healthy/1231.jpg
#   inflating: /content/image_dataset/healthy/1232.jpg
#   inflating: /content/image_dataset/healthy/1233.jpg
#   inflating: /content/image_dataset/healthy/1234.jpg
#   inflating: /content/image_dataset/healthy/1235.jpg
#   inflating: /content/image_dataset/healthy/1236.jpg
#   inflating: /content/image_dataset/healthy/1237.jpg
#   inflating: /content/image_dataset/healthy/1238.jpg
#   inflating: /content/image_dataset/healthy/1239.jpg
#   inflating: /content/image_dataset/healthy/1240.jpg
#   inflating: /content/image_dataset/healthy/1241.jpg
#   inflating: /content/image_dataset/healthy/1242.jpg
#   inflating: /content/image_dataset/healthy/1243.jpg
#   inflating: /content/image_dataset/healthy/1244.jpg
#   inflating: /content/image_dataset/healthy/1245.jpg
#   inflating: /content/image_dataset/healthy/1246.jpg
#   inflating: /content/image_dataset/healthy/1247.jpg
#   inflating: /content/image_dataset/healthy/1248.jpg
#   inflating: /content/image_dataset/healthy/1249.jpg
#   inflating: /content/image_dataset/healthy/1250.jpg
#   inflating: /content/image_dataset/healthy/1251.jpg
#   inflating: /content/image_dataset/healthy/1252.jpg
#   inflating: /content/image_dataset/healthy/1253.jpg
#   inflating: /content/image_dataset/healthy/1254.jpg
#   inflating: /content/image_dataset/healthy/1255.jpg
#   inflating: /content/image_dataset/healthy/1256.jpg
#   inflating: /content/image_dataset/healthy/1257.jpg
#   inflating: /content/image_dataset/healthy/1258.jpg
#   inflating: /content/image_dataset/healthy/1259.jpg
#   inflating: /content/image_dataset/healthy/1260.jpg
#   inflating: /content/image_dataset/healthy/1261.jpg
#   inflating: /content/image_dataset/healthy/1262.jpg
#   inflating: /content/image_dataset/healthy/1263.jpg
#   inflating: /content/image_dataset/healthy/1264.jpg
#   inflating: /content/image_dataset/healthy/1265.jpg
#   inflating: /content/image_dataset/healthy/1266.jpg
#   inflating: /content/image_dataset/healthy/1267.jpg
#   inflating: /content/image_dataset/healthy/1268.jpg
#   inflating: /content/image_dataset/healthy/1269.jpg
#   inflating: /content/image_dataset/healthy/1270.jpg
#   inflating: /content/image_dataset/healthy/1271.jpg
#   inflating: /content/image_dataset/healthy/1272.jpg
# ...
#   inflating: /content/image_dataset/pituitary/1477.jpg
#   inflating: /content/image_dataset/pituitary/1478.jpg
#   inflating: /content/image_dataset/pituitary/1479.jpg
#   inflating: /content/image_dataset/pituitary/1480.jpg
#   inflating: /content/image_dataset/pituitary/1481.jpg
#   inflating: /content/image_dataset/pituitary/1482.jpg
#   inflating: /content/image_dataset/pituitary/1483.jpg
#   inflating: /content/image_dataset/pituitary/1484.jpg
#   inflating: /content/image_dataset/pituitary/1485.jpg
#   inflating: /content/image_dataset/pituitary/1486.jpg
#   inflating: /content/image_dataset/pituitary/1487.jpg
#   inflating: /content/image_dataset/pituitary/1488.jpg
#   inflating: /content/image_dataset/pituitary/1489.jpg
#   inflating: /content/image_dataset/pituitary/1490.jpg
#   inflating: /content/image_dataset/pituitary/1491.jpg
#   inflating: /content/image_dataset/pituitary/1492.jpg
#   inflating: /content/image_dataset/pituitary/1493.jpg
#   inflating: /content/image_dataset/pituitary/1494.jpg
#   inflating: /content/image_dataset/pituitary/1495.jpg
#   inflating: /content/image_dataset/pituitary/1496.jpg
#   inflating: /content/image_dataset/pituitary/1497.jpg
#   inflating: /content/image_dataset/pituitary/1498.jpg
#   inflating: /content/image_dataset/pituitary/1499.jpg
#   inflating: /content/image_dataset/pituitary/1500.jpg
#   inflating: /content/image_dataset/pituitary/1501.jpg
#   inflating: /content/image_dataset/pituitary/1502.jpg
#   inflating: /content/image_dataset/pituitary/1503.jpg
#   inflating: /content/image_dataset/pituitary/1504.jpg
#   inflating: /content/image_dataset/pituitary/1505.jpg
#   inflating: /content/image_dataset/pituitary/1506.jpg
#   inflating: /content/image_dataset/pituitary/1507.jpg
#   inflating: /content/image_dataset/pituitary/1508.jpg
#   inflating: /content/image_dataset/pituitary/1509.jpg
#   inflating: /content/image_dataset/pituitary/1510.jpg
#   inflating: /content/image_dataset/pituitary/1511.jpg
#   inflating: /content/image_dataset/pituitary/1512.jpg
#   inflating: /content/image_dataset/pituitary/1513.jpg
#   inflating: /content/image_dataset/pituitary/1514.jpg
#   inflating: /content/image_dataset/pituitary/1515.jpg
#   inflating: /content/image_dataset/pituitary/1516.jpg
#   inflating: /content/image_dataset/pituitary/1517.jpg
#   inflating: /content/image_dataset/pituitary/1518.jpg
#   inflating: /content/image_dataset/pituitary/1519.jpg
#   inflating: /content/image_dataset/pituitary/1520.jpg
#   inflating: /content/image_dataset/pituitary/1521.jpg
#   inflating: /content/image_dataset/pituitary/1522.jpg
#   inflating: /content/image_dataset/pituitary/1523.jpg
#   inflating: /content/image_dataset/pituitary/1524.jpg
#   inflating: /content/image_dataset/pituitary/1525.jpg
#   inflating: /content/image_dataset/pituitary/1526.jpg
#   inflating: /content/image_dataset/pituitary/1527.jpg
#   inflating: /content/image_dataset/pituitary/1528.jpg
#   inflating: /content/image_dataset/pituitary/1529.jpg
#   inflating: /content/image_dataset/pituitary/1530.jpg
#   inflating: /content/image_dataset/pituitary/1531.jpg
#   inflating: /content/image_dataset/pituitary/1532.jpg
#   inflating: /content/image_dataset/pituitary/1533.jpg
#   inflating: /content/image_dataset/pituitary/1534.jpg
#   inflating: /content/image_dataset/pituitary/1535.jpg
#   inflating: /content/image_dataset/pituitary/1536.jpg
#   inflating: /content/image_dataset/pituitary/1537.jpg
#   inflating: /content/image_dataset/pituitary/1538.jpg
#   inflating: /content/image_dataset/pituitary/1539.jpg
#   inflating: /content/image_dataset/pituitary/1540.jpg
#   inflating: /content/image_dataset/pituitary/1541.jpg
#   inflating: /content/image_dataset/pituitary/1542.jpg
#   inflating: /content/image_dataset/pituitary/1543.jpg
#   inflating: /content/image_dataset/pituitary/1544.jpg
#   inflating: /content/image_dataset/pituitary/1545.jpg
#   inflating: /content/image_dataset/pituitary/1546.jpg
#   inflating: /content/image_dataset/pituitary/1547.jpg
#   inflating: /content/image_dataset/pituitary/1548.jpg
#   inflating: /content/image_dataset/pituitary/1549.jpg
#   inflating: /content/image_dataset/pituitary/1550.jpg
#   inflating: /content/image_dataset/pituitary/1551.jpg
#   inflating: /content/image_dataset/pituitary/1552.jpg
#   inflating: /content/image_dataset/pituitary/1553.jpg
#   inflating: /content/image_dataset/pituitary/1554.jpg
#   inflating: /content/image_dataset/pituitary/1555.jpg
#   inflating: /content/image_dataset/pituitary/1556.jpg
#   inflating: /content/image_dataset/pituitary/1557.jpg
#   inflating: /content/image_dataset/pituitary/1558.jpg
#   inflating: /content/image_dataset/pituitary/1559.jpg
#   inflating: /content/image_dataset/pituitary/1560.jpg
#   inflating: /content/image_dataset/pituitary/1561.jpg
#   inflating: /content/image_dataset/pituitary/1562.jpg
#   inflating: /content/image_dataset/pituitary/1563.jpg
#   inflating: /content/image_dataset/pituitary/1564.jpg
#   inflating: /content/image_dataset/pituitary/1565.jpg
#   inflating: /content/image_dataset/pituitary/1566.jpg
#   inflating: /content/image_dataset/pituitary/1567.jpg
#   inflating: /content/image_dataset/pituitary/1568.jpg
#   inflating: /content/image_dataset/pituitary/1569.jpg
#   inflating: /content/image_dataset/pituitary/1570.jpg
#   inflating: /content/image_dataset/pituitary/1571.jpg
#   inflating: /content/image_dataset/pituitary/1572.jpg
#   inflating: /content/image_dataset/pituitary/1573.jpg
#   inflating: /content/image_dataset/pituitary/1574.jpg
#   inflating: /content/image_dataset/pituitary/1575.jpg
#   inflating: /content/image_dataset/pituitary/1576.jpg
#   inflating: /content/image_dataset/pituitary/1577.jpg
#   inflating: /content/image_dataset/pituitary/1578.jpg
#   inflating: /content/image_dataset/pituitary/1579.jpg
#   inflating: /content/image_dataset/pituitary/1580.jpg
#   inflating: /content/image_dataset/pituitary/1581.jpg
#   inflating: /content/image_dataset/pituitary/1582.jpg
#   inflating: /content/image_dataset/pituitary/1583.jpg
#   inflating: /content/image_dataset/pituitary/1584.jpg
#   inflating: /content/image_dataset/pituitary/1585.jpg
#   inflating: /content/image_dataset/pituitary/1586.jpg
#   inflating: /content/image_dataset/pituitary/1587.jpg
#   inflating: /content/image_dataset/pituitary/1588.jpg
#   inflating: /content/image_dataset/pituitary/1589.jpg
#   inflating: /content/image_dataset/pituitary/1590.jpg
#   inflating: /content/image_dataset/pituitary/1591.jpg
#   inflating: /content/image_dataset/pituitary/1592.jpg
#   inflating: /content/image_dataset/pituitary/1593.jpg
#   inflating: /content/image_dataset/pituitary/1594.jpg
#   inflating: /content/image_dataset/pituitary/1595.jpg
#   inflating: /content/image_dataset/pituitary/1596.jpg
#   inflating: /content/image_dataset/pituitary/1597.jpg
#   inflating: /content/image_dataset/pituitary/1598.jpg
#   inflating: /content/image_dataset/pituitary/1599.jpg
#   inflating: /content/image_dataset/pituitary/1600.jpg
#   inflating: /content/image_dataset/pituitary/1601.jpg
#   inflating: /content/image_dataset/pituitary/1602.jpg
#   inflating: /content/image_dataset/pituitary/1603.jpg
#   inflating: /content/image_dataset/pituitary/1604.jpg
#   inflating: /content/image_dataset/pituitary/1605.jpg
#   inflating: /content/image_dataset/pituitary/1606.jpg
#   inflating: /content/image_dataset/pituitary/1607.jpg
#   inflating: /content/image_dataset/pituitary/1608.jpg
#   inflating: /content/image_dataset/pituitary/1609.jpg
#   inflating: /content/image_dataset/pituitary/1610.jpg
#   inflating: /content/image_dataset/pituitary/1611.jpg
#   inflating: /content/image_dataset/pituitary/1612.jpg
#   inflating: /content/image_dataset/pituitary/1613.jpg
#   inflating: /content/image_dataset/pituitary/1614.jpg
#   inflating: /content/image_dataset/pituitary/1615.jpg
#   inflating: /content/image_dataset/pituitary/1616.jpg
#   inflating: /content/image_dataset/pituitary/1617.jpg
#   inflating: /content/image_dataset/pituitary/1618.jpg
#   inflating: /content/image_dataset/pituitary/1619.jpg
#   inflating: /content/image_dataset/pituitary/1620.jpg
#   inflating: /content/image_dataset/pituitary/1621.jpg
#   inflating: /content/image_dataset/pituitary/1622.jpg
#   inflating: /content/image_dataset/pituitary/1623.jpg
#   inflating: /content/image_dataset/pituitary/1624.jpg
#   inflating: /content/image_dataset/pituitary/1625.jpg
#   inflating: /content/image_dataset/pituitary/1626.jpg
#   inflating: /content/image_dataset/pituitary/1627.jpg
#   inflating: /content/image_dataset/pituitary/1628.jpg
#   inflating: /content/image_dataset/pituitary/1629.jpg
#   inflating: /content/image_dataset/pituitary/1630.jpg
#   inflating: /content/image_dataset/pituitary/1631.jpg
#   inflating: /content/image_dataset/pituitary/1632.jpg
#   inflating: /content/image_dataset/pituitary/1633.jpg
#   inflating: /content/image_dataset/pituitary/1634.jpg
#   inflating: /content/image_dataset/pituitary/1635.jpg
#   inflating: /content/image_dataset/pituitary/1636.jpg
#   inflating: /content/image_dataset/pituitary/1637.jpg
#   inflating: /content/image_dataset/pituitary/1638.jpg
#   inflating: /content/image_dataset/pituitary/1639.jpg
#   inflating: /content/image_dataset/pituitary/1640.jpg
#   inflating: /content/image_dataset/pituitary/1641.jpg
#   inflating: /content/image_dataset/pituitary/1642.jpg
#   inflating: /content/image_dataset/pituitary/1643.jpg
#   inflating: /content/image_dataset/pituitary/1644.jpg
#   inflating: /content/image_dataset/pituitary/1645.jpg
#   inflating: /content/image_dataset/pituitary/1646.jpg
#   inflating: /content/image_dataset/pituitary/1647.jpg
#   inflating: /content/image_dataset/pituitary/1648.jpg
#   inflating: /content/image_dataset/pituitary/1649.jpg
#   inflating: /content/image_dataset/pituitary/1650.jpg
#   inflating: /content/image_dataset/pituitary/1651.jpg
#   inflating: /content/image_dataset/pituitary/1652.jpg
#   inflating: /content/image_dataset/pituitary/1653.jpg
#   inflating: /content/image_dataset/pituitary/1654.jpg
#   inflating: /content/image_dataset/pituitary/1655.jpg
#   inflating: /content/image_dataset/pituitary/1656.jpg
#   inflating: /content/image_dataset/pituitary/1657.jpg
#   inflating: /content/image_dataset/pituitary/1658.jpg
#   inflating: /content/image_dataset/pituitary/1659.jpg
#   inflating: /content/image_dataset/pituitary/1660.jpg
#   inflating: /content/image_dataset/pituitary/1661.jpg
#   inflating: /content/image_dataset/pituitary/1662.jpg
#   inflating: /content/image_dataset/pituitary/1663.jpg
#   inflating: /content/image_dataset/pituitary/1664.jpg
#   inflating: /content/image_dataset/pituitary/1665.jpg
#   inflating: /content/image_dataset/pituitary/1666.jpg
#   inflating: /content/image_dataset/pituitary/1667.jpg
#   inflating: /content/image_dataset/pituitary/1668.jpg
#   inflating: /content/image_dataset/pituitary/1669.jpg
#   inflating: /content/image_dataset/pituitary/1670.jpg
#   inflating: /content/image_dataset/pituitary/1671.jpg
#   inflating: /content/image_dataset/pituitary/1672.jpg
#   inflating: /content/image_dataset/pituitary/1673.jpg
#   inflating: /content/image_dataset/pituitary/1674.jpg
#   inflating: /content/image_dataset/pituitary/1675.jpg
#   inflating: /content/image_dataset/pituitary/1676.jpg
#   inflating: /content/image_dataset/pituitary/1677.jpg
#   inflating: /content/image_dataset/pituitary/1678.jpg
#   inflating: /content/image_dataset/pituitary/1679.jpg
#   inflating: /content/image_dataset/pituitary/1680.jpg
#   inflating: /content/image_dataset/pituitary/1681.jpg
#   inflating: /content/image_dataset/pituitary/1682.jpg
#   inflating: /content/image_dataset/pituitary/1683.jpg
#   inflating: /content/image_dataset/pituitary/1684.jpg
#   inflating: /content/image_dataset/pituitary/1685.jpg
#   inflating: /content/image_dataset/pituitary/1686.jpg
#   inflating: /content/image_dataset/pituitary/1687.jpg
#   inflating: /content/image_dataset/pituitary/1688.jpg
#   inflating: /content/image_dataset/pituitary/1689.jpg
#   inflating: /content/image_dataset/pituitary/1690.jpg
#   inflating: /content/image_dataset/pituitary/1691.jpg
#   inflating: /content/image_dataset/pituitary/1692.jpg
#   inflating: /content/image_dataset/pituitary/1693.jpg
#   inflating: /content/image_dataset/pituitary/1694.jpg
#   inflating: /content/image_dataset/pituitary/1695.jpg
#   inflating: /content/image_dataset/pituitary/1696.jpg
#   inflating: /content/image_dataset/pituitary/1697.jpg
#   inflating: /content/image_dataset/pituitary/1698.jpg
#   inflating: /content/image_dataset/pituitary/1699.jpg
#   inflating: /content/image_dataset/pituitary/1700.jpg
#   inflating: /content/image_dataset/pituitary/1701.jpg
#   inflating: /content/image_dataset/pituitary/1702.jpg
#   inflating: /content/image_dataset/pituitary/1703.jpg
#   inflating: /content/image_dataset/pituitary/1704.jpg
#   inflating: /content/image_dataset/pituitary/1705.jpg
#   inflating: /content/image_dataset/pituitary/1706.jpg
#   inflating: /content/image_dataset/pituitary/1707.jpg
#   inflating: /content/image_dataset/pituitary/1708.jpg
#   inflating: /content/image_dataset/pituitary/1709.jpg
#   inflating: /content/image_dataset/pituitary/1710.jpg
#   inflating: /content/image_dataset/pituitary/1711.jpg
#   inflating: /content/image_dataset/pituitary/1712.jpg
#   inflating: /content/image_dataset/pituitary/1713.jpg
#   inflating: /content/image_dataset/pituitary/1714.jpg
#   inflating: /content/image_dataset/pituitary/1715.jpg
#   inflating: /content/image_dataset/pituitary/1716.jpg
#   inflating: /content/image_dataset/pituitary/1717.jpg
#   inflating: /content/image_dataset/pituitary/1718.jpg
#   inflating: /content/image_dataset/pituitary/1719.jpg
#   inflating: /content/image_dataset/pituitary/1720.jpg
#   inflating: /content/image_dataset/pituitary/1721.jpg
#   inflating: /content/image_dataset/pituitary/1722.jpg
#   inflating: /content/image_dataset/pituitary/1723.jpg
#   inflating: /content/image_dataset/pituitary/1724.jpg
#   inflating: /content/image_dataset/pituitary/1725.jpg
#   inflating: /content/image_dataset/pituitary/1726.jpg
#   inflating: /content/image_dataset/pituitary/1727.jpg
#   inflating: /content/image_dataset/pituitary/1728.jpg
#   inflating: /content/image_dataset/pituitary/1729.jpg
#   inflating: /content/image_dataset/pituitary/1730.jpg
#   inflating: /content/image_dataset/pituitary/1731.jpg
#   inflating: /content/image_dataset/pituitary/1732.jpg
#   inflating: /content/image_dataset/pituitary/1733.jpg
#   inflating: /content/image_dataset/pituitary/1734.jpg
#   inflating: /content/image_dataset/pituitary/1735.jpg
#   inflating: /content/image_dataset/pituitary/1736.jpg
#   inflating: /content/image_dataset/pituitary/1737.jpg
#   inflating: /content/image_dataset/pituitary/1738.jpg
#   inflating: /content/image_dataset/pituitary/1739.jpg
#   inflating: /content/image_dataset/pituitary/1740.jpg
#   inflating: /content/image_dataset/pituitary/1741.jpg
#   inflating: /content/image_dataset/pituitary/1742.jpg
#   inflating: /content/image_dataset/pituitary/1743.jpg
#   inflating: /content/image_dataset/pituitary/1744.jpg
#   inflating: /content/image_dataset/pituitary/1745.jpg
#   inflating: /content/image_dataset/pituitary/1746.jpg
#   inflating: /content/image_dataset/pituitary/1747.jpg
#   inflating: /content/image_dataset/pituitary/1748.jpg
#   inflating: /content/image_dataset/pituitary/1749.jpg
#   inflating: /content/image_dataset/pituitary/1750.jpg
#   inflating: /content/image_dataset/pituitary/1751.jpg
#   inflating: /content/image_dataset/pituitary/1752.jpg
#   inflating: /content/image_dataset/pituitary/1753.jpg
#   inflating: /content/image_dataset/pituitary/1754.jpg
#   inflating: /content/image_dataset/pituitary/1755.jpg
#   inflating: /content/image_dataset/pituitary/1756.jpg

# %%
# Loading and Preparing Anime Face Images Dataset using Keras Image Data Generator
img_width, img_height = 256, 256
batchsize = 32

train = keras. utils.image_dataset_from_directory(
    directory='/content/image_dataset',
    batch_size = batchsize,
    image_size = (img_width, img_height))
# Out:
# Found 7023 files belonging to 4 classes.

# %%
# Generating Augmented Batches of Anime Face Images using ImageDataGenerator
DIR = '/content/image_dataset' #path

# Create an ImageDataGenerator object with data augmentation options for image preprocessing
train_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip = True)


train_generator = train_datagen.flow_from_directory(
        DIR,
        target_size = (64, 64),
        batch_size = batchsize,
        class_mode = None)

#train_generator[0]
# Out:
# Found 7023 images belonging to 4 classes.

# %%
# Visualizing a Batch of Face Images

data_iterator = train.as_numpy_iterator()
batch = data_iterator.next()
fig, ax = plt.subplots(ncols=4, figsize=(10,10))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
# Creating the Generator Model

KI = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)
input_dim = 300

def Generator_Model():

    Generator = Sequential()

    # Random noise
    Generator.add(Dense(8 * 8 * 512, input_dim = input_dim))
    Generator.add(ReLU())
    # Convert 1d to 3d
    Generator.add(Reshape((8, 8, 512)))
    # Unsample
    Generator.add(Conv2DTranspose(256, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2D(3, (4, 4), padding='same', activation='sigmoid'))


    return Generator

generator = Generator_Model()
generator.summary()
# Visualized Layers of generator
keras.utils.plot_model(generator, show_shapes=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32768)               │       9,863,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 8, 8, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 16, 16, 256)         │       2,097,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_1 (Conv2DTranspose) │ (None, 32, 32, 128)         │         524,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_2 (Conv2DTranspose) │ (None, 64, 64, 64)          │         131,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 64, 64, 3)           │           3,075 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,619,203 (48.14 MB)
#  Trainable params: 12,619,203 (48.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Creating the Discriminator Model

KI = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)
input_dim = 300

def Discriminator_Model(input_shape=(64, 64, 3)):
    """Creates a discriminator model for a GAN."""

    # Initialize the Sequential model
    discriminator = Sequential()

    # First convolutional block
    discriminator.add(Conv2D(64, kernel_size=(3, 3), input_shape=input_shape))
    discriminator.add(LeakyReLU())  # Add LeakyReLU as a separate layer
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))

    # Second convolutional block
    discriminator.add(Conv2D(128, kernel_size=(3, 3)))
    discriminator.add(LeakyReLU())  # Add LeakyReLU as a separate layer
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))

    # Third convolutional block
    discriminator.add(Conv2D(256, kernel_size=(3, 3)))
    discriminator.add(LeakyReLU())  # Add LeakyReLU as a separate layer
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))

    # Flatten and dense layers
    discriminator.add(Flatten())
    discriminator.add(Dense(256))
    discriminator.add(LeakyReLU())  # Add LeakyReLU as a separate layer
    discriminator.add(Dense(1, activation='sigmoid'))

    return discriminator

# Instantiate and summarize the discriminator model
# Changed line: calling the correctly named function 'Discriminator_Model'
discriminator = Discriminator_Model()
discriminator.summary()

# Visualize the layers of the discriminator model
keras.utils.plot_model(discriminator, show_shapes=True)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)                    │ (None, 62, 62, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 31, 31, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 29, 29, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 29, 29, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 12, 12, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 9216)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │       2,359,552 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,730,625 (10.42 MB)
#  Trainable params: 2,730,625 (10.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# DCGAN Model Training Step with Discriminator and Generator

class DCGAN(keras.Model):
    def __init__(self, generator, discriminator, latent_dim = input_dim):
        super().__init__()
        self.generator = generator
        self.discriminator = discriminator
        self.latent_dim = latent_dim
        self.g_loss_metric = keras.metrics.Mean(name='g_loss')
        self.d_loss_metric = keras.metrics.Mean(name='d_loss')

    @property
    def metrics(self):
        return [self.g_loss_metric, self.d_loss_metric]

    def compile(self, g_optimizer, d_optimizer, loss_fn):
        super(DCGAN, self).compile()
        self.g_optimizer = g_optimizer
        self.d_optimizer = d_optimizer
        self.loss_fn = loss_fn

    def train_step(self, real_images):
        # get batch size from the data
        batch_size = tf.shape(real_images)[0]
        # generate random noise
        random_noise = tf.random.normal(shape=(batch_size, self.latent_dim))

        # train the discriminator with real (1) and fake (0) images
        with tf.GradientTape() as tape:
            # compute loss on real images
            pred_real = self.discriminator(real_images, training=True)
            # generate real image labels
            real_labels = tf.ones((batch_size, 1))
            # label smoothing
            real_labels += 0.05 * tf.random.uniform(tf.shape(real_labels))
            d_loss_real = self.loss_fn(real_labels, pred_real)

            # compute loss on fake images
            fake_images = self.generator(random_noise)
            pred_fake = self.discriminator(fake_images, training=True)
            # generate fake labels
            fake_labels = tf.zeros((batch_size, 1))
            d_loss_fake = self.loss_fn(fake_labels, pred_fake)

            # total discriminator loss
            d_loss = (d_loss_real + d_loss_fake) / 2

        # compute discriminator gradients
        gradients = tape.gradient(d_loss, self.discriminator.trainable_variables)
        # update the gradients
        self.d_optimizer.apply_gradients(zip(gradients, self.discriminator.trainable_variables))


        # train the generator model
        labels = tf.ones((batch_size, 1))
        # generator want discriminator to think that fake images are real
        with tf.GradientTape() as tape:
            # generate fake images from generator
            fake_images = self.generator(random_noise, training=True)
            # classify images as real or fake
            pred_fake = self.discriminator(fake_images, training=True)
            # compute loss
            g_loss = self.loss_fn(labels, pred_fake)

        # compute gradients
        gradients = tape.gradient(g_loss, self.generator.trainable_variables)
        # update the gradients
        self.g_optimizer.apply_gradients(zip(gradients, self.generator.trainable_variables))

        # update states for both models
        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)

        return {'d_loss': self.d_loss_metric.result(), 'g_loss': self.g_loss_metric.result()}

# %%
# DCGAN Monitor for Image Generation and Model Saving

class DCGANMonitor(keras.callbacks.Callback):
    def __init__(self, num_imgs=25, latent_dim = input_dim):
        self.num_imgs = num_imgs
        self.latent_dim = latent_dim
        # create random noise for generating images
        self.noise = tf.random.normal([25, latent_dim])

    def on_epoch_end(self, epoch, logs = None):
        # generate the image from noise
        g_img = self.model.generator(self.noise)
        # denormalize the image
        g_img = (g_img * 255) + 255
        g_img.numpy()

    def on_train_end(self, logs = None):
        self.model.generator.save('DCGEN.h5')

# %%
# Training DCGAN on Image Dataset for 40 Epochs

epochs = 70
lr_g =0.0003
lr_d = 0.0001
beta = 0.5
latent_dim = 300

dcgan = DCGAN(generator=generator, discriminator=discriminator, latent_dim = latent_dim )
dcgan.compile(g_optimizer = Adam (learning_rate= lr_g, beta_1= beta), d_optimizer= Adam (learning_rate = lr_g , beta_1= beta), loss_fn = BinaryCrossentropy())

# %%
#train the model

history = dcgan.fit(train_generator, epochs=epochs, callbacks=[DCGANMonitor(num_imgs=25, latent_dim = latent_dim)])
# Out:
# Epoch 1/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 33s 78ms/step - d_loss: 1.7698 - g_loss: 2.4594
# Epoch 2/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 23s 52ms/step - d_loss: 0.3063 - g_loss: 2.2029
# Epoch 3/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - d_loss: 0.1443 - g_loss: 2.8844
# Epoch 4/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - d_loss: 0.1708 - g_loss: 3.5767
# Epoch 5/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: 0.2443 - g_loss: 3.1659
# Epoch 6/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: 0.2575 - g_loss: 3.1142
# Epoch 7/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - d_loss: 0.2564 - g_loss: 3.0884
# Epoch 8/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: 0.2479 - g_loss: 2.9579
# Epoch 9/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - d_loss: 0.2594 - g_loss: 2.8280
# Epoch 10/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - d_loss: 0.3406 - g_loss: 2.8669
# Epoch 11/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - d_loss: 0.1877 - g_loss: 3.4925
# Epoch 12/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - d_loss: 0.2367 - g_loss: 3.2914
# Epoch 13/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - d_loss: 0.1973 - g_loss: 3.4348
# Epoch 14/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: 0.2683 - g_loss: 4.0382
# Epoch 15/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: 0.1826 - g_loss: 3.5470
# Epoch 16/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: 0.2292 - g_loss: 4.4570
# Epoch 17/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - d_loss: 0.1361 - g_loss: 4.0416
# Epoch 18/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 51ms/step - d_loss: 0.1396 - g_loss: 4.4628
# Epoch 19/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 52ms/step - d_loss: 0.2075 - g_loss: 4.7751
# Epoch 20/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - d_loss: 0.1280 - g_loss: 4.2380
# Epoch 21/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - d_loss: 0.0494 - g_loss: 4.7221
# Epoch 22/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - d_loss: 0.1812 - g_loss: 4.4609
# Epoch 23/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: 0.0801 - g_loss: 4.1778
# Epoch 24/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: -0.0447 - g_loss: 5.6743
# Epoch 25/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - d_loss: 0.1873 - g_loss: 5.0624
# Epoch 26/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - d_loss: 0.3371 - g_loss: 5.7938
# Epoch 27/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - d_loss: -0.0401 - g_loss: 5.0069
# Epoch 28/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - d_loss: -0.0330 - g_loss: 5.1632
# Epoch 29/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: -0.1261 - g_loss: 6.8699
# Epoch 30/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - d_loss: -0.5125 - g_loss: 8.4829
# Epoch 31/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: -0.4957 - g_loss: 6.6538
# Epoch 32/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - d_loss: -0.5953 - g_loss: 7.1706
# Epoch 33/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - d_loss: 0.8130 - g_loss: 8.3894
# Epoch 34/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: 0.5180 - g_loss: 8.5937
# Epoch 35/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - d_loss: -0.4781 - g_loss: 7.1982
# Epoch 36/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - d_loss: -0.2290 - g_loss: 10.7673
# Epoch 37/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 13s 56ms/step - d_loss: -1.7862 - g_loss: 11.3306
# Epoch 38/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: 0.1706 - g_loss: 11.3430
# Epoch 39/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: 0.8848 - g_loss: 9.6896
# Epoch 40/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: 0.7785 - g_loss: 6.9148
# Epoch 41/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: -0.7037 - g_loss: 8.1985
# Epoch 42/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - d_loss: -0.0111 - g_loss: 8.0387
# Epoch 43/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: -2.4412 - g_loss: 9.7823
# Epoch 44/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - d_loss: -0.1518 - g_loss: 7.0358
# Epoch 45/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - d_loss: -4.2496 - g_loss: 11.9104
# Epoch 46/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: 1.2018 - g_loss: 8.2702
# Epoch 47/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - d_loss: 0.3126 - g_loss: 8.0476
# Epoch 48/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: -1.3579 - g_loss: 10.1645
# Epoch 49/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - d_loss: -1.6499 - g_loss: 11.3552
# Epoch 50/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - d_loss: -2.2250 - g_loss: 9.3389
# Epoch 51/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - d_loss: -2.3964 - g_loss: 9.8062
# Epoch 52/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: 8.2487 - g_loss: 12.7935
# Epoch 53/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: 0.6857 - g_loss: 7.3369
# Epoch 54/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: 0.5536 - g_loss: 7.2036
# Epoch 55/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: -2.5784 - g_loss: 10.7471
# Epoch 56/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - d_loss: 0.4132 - g_loss: 9.8818
# Epoch 57/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - d_loss: -7.5558 - g_loss: 17.8473
# Epoch 58/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - d_loss: -2.8072 - g_loss: 12.5101
# Epoch 59/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: -4.8796 - g_loss: 14.4924
# Epoch 60/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - d_loss: -3.7256 - g_loss: 16.6894
# Epoch 61/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: -6.5731 - g_loss: 15.8721
# Epoch 62/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - d_loss: 24.8565 - g_loss: 20.6733
# Epoch 63/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - d_loss: -1.5639 - g_loss: 9.0648
# Epoch 64/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: -5.9326 - g_loss: 13.8648
# Epoch 65/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - d_loss: -7.0368 - g_loss: 16.6389
# Epoch 66/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - d_loss: -3.7483 - g_loss: 14.9513
# Epoch 67/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - d_loss: 45.0164 - g_loss: 21.1368
# Epoch 68/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - d_loss: 0.6872 - g_loss: 14.9531
# Epoch 69/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - d_loss: -2.4369 - g_loss: 9.6505
# Epoch 70/70
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - d_loss: -6.9482 - g_loss: 12.4552
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# prompt: plot the generating images

import matplotlib.pyplot as plt
import numpy as np

# Assuming 'dcgan' and 'latent_dim' are defined from the previous code
# and 'DCGEN.h5' has been saved during training.

# Load the trained generator
generator = keras.models.load_model('DCGEN.h5')

# Generate images
num_images = 25
noise = tf.random.normal([num_images, latent_dim])
generated_images = generator(noise)

# Display the generated images
fig, axes = plt.subplots(5, 5, figsize=(10, 10))
for i, ax in enumerate(axes.flat):
    ax.imshow(generated_images[i])
    ax.axis('off')
plt.show()
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
import matplotlib.pyplot as plt

# Function to create a figure for the losses
def create_loss_figure(d_loss_values, g_loss_values):
    plt.figure(figsize=(10, 6))
    plt.plot(d_loss_values, label='Discriminator Loss')
    plt.plot(g_loss_values, label='Generator Loss')
    plt.title('Generator and Discriminator Losses')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# Access the loss values from the history
d_loss_values = history.history['d_loss']
g_loss_values = history.history['g_loss']

# Call the create_loss_figure function with the loss values
create_loss_figure(d_loss_values, g_loss_values)

# %%
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import peak_signal_noise_ratio as psnr
import cv2

# Assuming 'dcgan' is your trained DCGAN model and 'train_generator' provides real images
# You'll need to adapt this to your specific data and how you access it.

# Example using a single batch of real images
real_images = next(iter(train_generator))

# Generate corresponding fake images
noise = tf.random.normal([real_images.shape[0], 300]) #Match batch size of real_images
fake_images = dcgan.generator(noise)


# Assuming your images are in the range [0, 255] and are normalized to [0,1] in the model
fake_images = (fake_images * 255) #Denormalize
fake_images = fake_images.numpy()

#Calculate PSNR and SSIM for each image pair
psnr_values = []
ssim_values = []

for i in range (real_images.shape[0]):
  real = np.uint8(real_images[i] * 255) #Denormalize and convert to uint8
  fake = np.uint8(fake_images[i])

  #Convert to grayscale for SSIM calculation (optional but recommended)
  real_gray = cv2.cvtColor(real, cv2.COLOR_BGR2GRAY)
  fake_gray = cv2.cvtColor(fake, cv2.COLOR_BGR2GRAY)

  psnr_value = psnr(real, fake)
  ssim_value = ssim(real_gray, fake_gray)

  psnr_values.append(psnr_value)
  ssim_values.append(ssim_value)

#Print or process the results
print("PSNR Values:", psnr_values)
print("SSIM Values:", ssim_values)

#Calculate and print average PSNR and SSIM
avg_psnr = np.mean(psnr_values)
avg_ssim = np.mean(ssim_values)

print(f"Average PSNR: {avg_psnr}")
print(f"Average SSIM: {avg_ssim}")
# Out:
# PSNR Values: [14.3978406828063, 11.893605486001704, 13.589946614469405, 14.946125372593354, 14.504401752524188, 13.875931342104877, 12.925860920980574, 15.376037413974347, 14.089218857902303, 15.206797499778077, 14.600698006031363, 14.218624870985687, 14.960068557881687, 13.271913186027312, 14.197707323577045, 14.551060958377352, 15.034952407468689, 13.494876480492518, 16.337357214548987, 13.16458452010828, 14.373335091560925, 13.201095900486033, 15.586484374483671, 14.60446598243854, 8.563648733870641, 13.044708453373827, 11.953769565946072, 14.33011368473581, 14.417196717507391, 14.415858703474091, 15.262872217337083, 15.129066324752758]
# SSIM Values: [0.12623332693463266, 0.06758888513814797, 0.05142653182224376, 0.2034020583382424, 0.1170457495878583, 0.10489825152814936, 0.04925624797816203, 0.15001054936199476, 0.13153656087614876, 0.16041719637295843, 0.10685746397247674, 0.14871474700572604, 0.19949222952870246, 0.06742943955404047, 0.08067637295591969, 0.10800572305706872, 0.12206964682417637, 0.12277825833766465, 0.18598256224301668, 0.06297536187678751, 0.1050550810597779, 0.06639090864171268, 0.19944519018070825, 0.12008339597327689, 0.09299491305830818, 0.06374816204632228, 0.03077905244549424, 0.1449059805961047, 0.09818204591756821, 0.17809210533025333, 0.11561104019045944, 0.1701326042871349]
# Average PSNR: 14.047507038081278
# Average SSIM: 0.11725680134441371

# %%
# prompt: calculate the dice score

# Calculate Dice score
import numpy as np

def dice_score(real_images, fake_images):
    """
    Calculates the Dice score between two sets of images.

    Args:
        real_images: A NumPy array of real images.
        fake_images: A NumPy array of fake images.

    Returns:
        The Dice score as a float.
    """

    # Ensure images are binary
    real_images = np.round(real_images)  # Round to 0 or 1
    fake_images = np.round(fake_images)

    intersection = np.sum(real_images * fake_images, axis=(1, 2, 3))  # Sum along image dimensions
    sum_of_elements = np.sum(real_images, axis=(1, 2, 3)) + np.sum(fake_images, axis=(1, 2, 3))
    dice = (2. * intersection) / (sum_of_elements + 1e-9) # Added small epsilon to avoid division by zero

    return dice


dice_scores = dice_score(real_images, fake_images)

print("Dice Scores:", dice_scores)
avg_dice = np.mean(dice_scores)
print(f"Average Dice Score: {avg_dice}")
# Out:
# Dice Scores: [0.03170637 0.2753704  0.07803382 0.15039499 0.06959232 0.06385617
#  0.11681618 0.00405665 0.09729633 0.09154645 0.05880515 0.2777999
#  0.13414134 0.10057174 0.15324816 0.04663992 0.09018955 0.09125409
#  0.05458087 0.06723551 0.07439294 0.08176487 0.09785333 0.07040949
#  1.1919556  0.08137029 0.08387394 0.04206509 0.00994472 0.17873304
#  0.06117084 0.08837347]
# Average Dice Score: 0.12859511375427246
